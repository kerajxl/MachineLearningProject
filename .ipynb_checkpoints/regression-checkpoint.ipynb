# %% [markdown]
# # 1. Prepare necesary libraries

# %%
import pandas  as pd 
import seaborn as sns
import numpy as np 
import matplotlib.pyplot as plt 
from datetime import datetime as dt 
from sklearn.preprocessing import OneHotEncoder
# %matplotlib inline
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import VarianceThreshold

import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# # 2. Loading data and cleaning

# %%
traffic = pd.read_csv('traffic_train.csv')
traffic.head(10)
traffic['date_time'] = pd.to_datetime(traffic['date_time'])
traffic['day'] = traffic.date_time.dt.day
traffic.head()
# Out:
#             date_time weather_general weather_detailed  clouds_coverage_pct  \
# 0 2014-10-01 00:00:00           Clear     sky is clear                    1
# 1 2014-10-01 01:00:00           Clear     sky is clear                    1
# 2 2014-10-01 02:00:00           Clear     sky is clear                    1
# 3 2014-10-01 03:00:00           Clear     sky is clear                    1
# 4 2014-10-01 04:00:00           Clear     sky is clear                    1
#
#    temperature  rain_mm  snow_mm  traffic  day
# 0         11.5      0.0      0.0      508    1
# 1         10.3      0.0      0.0      323    1
# 2          8.0      0.0      0.0      274    1
# 3          7.9      0.0      0.0      372    1
# 4          6.4      0.0      0.0      812    1

# %%
def dayFromDate(traffic):
    traffic['date_time'] = pd.to_datetime(traffic['date_time'])
    traffic['hour'] = traffic.date_time.dt.hour
    traffic['hour_interval'] = pd.cut(traffic.hour, bins = [-1,6,12,18,24], labels = ['0-6','6-12', '12-18', '18-24'])
    traffic['day'] = traffic.date_time.dt.day_of_week  
    traffic['month'] = traffic.date_time.dt.month
    traffic['year'] = traffic.date_time.dt.year
    return(traffic)

dayFromDate(traffic)
# Out:
#                 date_time weather_general         weather_detailed  \
# 0     2014-10-01 00:00:00           Clear             sky is clear
# 1     2014-10-01 01:00:00           Clear             sky is clear
# 2     2014-10-01 02:00:00           Clear             sky is clear
# 3     2014-10-01 03:00:00           Clear             sky is clear
# 4     2014-10-01 04:00:00           Clear             sky is clear
# ...                   ...             ...                      ...
# 29696 2018-12-31 22:00:00            Mist                     mist
# 29697 2018-12-31 22:00:00            Snow               light snow
# 29698 2018-12-31 23:00:00            Mist                     mist
# 29699 2018-12-31 23:00:00            Snow               light snow
# 29700 2018-12-31 23:00:00         Drizzle  light intensity drizzle
#
#        clouds_coverage_pct  temperature  rain_mm  snow_mm  traffic  day  hour  \
# 0                        1         11.5      0.0      0.0      508    2     0
# 1                        1         10.3      0.0      0.0      323    2     1
# 2                        1          8.0      0.0      0.0      274    2     2
# 3                        1          7.9      0.0      0.0      372    2     3
# 4                        1          6.4      0.0      0.0      812    2     4
# ...                    ...          ...      ...      ...      ...  ...   ...
# 29696                   90         -0.2      0.0      0.0     1228    0    22
# 29697                   90         -0.2      0.0      0.0     1218    0    22
# 29698                   90         -0.1      0.0      0.0      830    0    23
# 29699                   90         -0.1      0.0      0.0      828    0    23
# 29700                   90         -0.1      0.0      0.0      824    0    23
#
#       hour_interval  month  year
# 0               0-6     10  2014
# 1               0-6     10  2014
# 2               0-6     10  2014
# 3               0-6     10  2014
# 4               0-6     10  2014
# ...             ...    ...   ...
# 29696         18-24     12  2018
# 29697         18-24     12  2018
# 29698         18-24     12  2018
# 29699         18-24     12  2018
# 29700         18-24     12  2018
#
# [29701 rows x 13 columns]

# %%
def ordinal_whether(traffic):
    traffic['ordinal_weather'] = np.where(traffic.weather_detailed.isin(['fog', 'freezing rain', 'heavy intensity rain','heavy snow','proximity thunderstorm',
                                 'proximity thunderstorm with drizzle', 'proximity thunderstorm with rain', 'sleet', 'squalls',
                                 'thunderstorm', 'thunderstorm with drizzle', 'thunderstorm with heavy rain', 'thunderstorm with light drizzle',
                                  'thunderstorm with light rain', 'thunderstorm with rain', 'very heavy rain']), 0, #fatalne
                                 np.where(traffic.weather_detailed.isin(['drizzle','haze', 'heavy intensity drizzle','light intensity drizzle','light intensity shower rain',
                                 'light rain', 'light rain and snow', 'light shower snow', 'light snow','mist', 'moderate rain', 'shower drizzle',
                                  'shower snow', 'smoke', 'snow', ]), 1, #kiepskie
                                 np.where(traffic.weather_detailed.isin(['broken clouds','few clouds', 'overcast clouds', 'proximity shower rain',
                                 ]), 2, #umiarkowane
                                 np.where(traffic.weather_detailed.isin(['scattered clouds', 'sky is clear', ]), 3, 99 )))) #dobre
    return (traffic)

traffic = ordinal_whether(traffic)

# %%
def weather_dummies(traffic):
    t1 = pd.get_dummies(traffic['weather_general'])
    t1['tmp'] = range(0,len(traffic.weather_detailed))
    traffic['tmp'] = range(0,len(traffic.weather_detailed))
    traffic = pd.merge(traffic, t1, on = ['tmp']).drop('tmp', axis = 1)
    traffic['Fog'] = traffic['Fog'] + traffic['Smoke']
    traffic['Rain'] = traffic['Rain'] + traffic['Squall']
    traffic.drop(['Smoke', 'Squall'], axis = 1)
    return(traffic)

traffic = weather_dummies(traffic)

# %%
numericalVar = ['clouds_coverage_pct', 'temperature', 'rain_mm', 'snow_mm', 'traffic']
fig, axs = plt.subplots(ncols=1, nrows=5, figsize=(12, 10),
                        constrained_layout=True)
for idx, col in enumerate(numericalVar):
    axs[idx].hist(traffic[f'{col}'])
    axs[idx].set_title(f'Variable: {col}')

# %%
traffic.temperature.loc[(traffic.temperature < -30)] = traffic.groupby(by = ['month']).mean().temperature[1]
traffic.rain_mm.loc[traffic.rain_mm > 1000] = traffic.rain_mm.loc[traffic.rain_mm < 1000].max()

# %%
numericalVar = ['clouds_coverage_pct', 'temperature', 'rain_mm', 'snow_mm', 'traffic']
fig, axs = plt.subplots(ncols=1, nrows=5, figsize=(12, 10),
                        constrained_layout=True)
for idx, col in enumerate(numericalVar):
    axs[idx].hist(traffic[f'{col}'])
    axs[idx].set_title(f'Variable: {col}')

# %% [markdown]
# # 3. Standarize data

# %%
# scale = StandardScaler()
# numericalData = traffic[numericalVar]

# scaledData = scale.fit_transform(numericalData)
# traffic[numericalVar] = pd.DataFrame(scaledData)

# traffic

# %% [markdown]
# # 4. Corrplot

# %%
corr = traffic.corr()
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True
corr[mask] = np.nan
(corr
 .style
 .background_gradient(cmap='coolwarm', axis=None, vmin=-1, vmax=1)
 .highlight_null(null_color='#f1f1f1')  # Color NaNs grey
 .set_precision(2))
# Out:
# <style type="text/css">
# #T_4d490_row0_col0, #T_4d490_row0_col1, #T_4d490_row0_col2, #T_4d490_row0_col3, #T_4d490_row0_col4, #T_4d490_row0_col5, #T_4d490_row0_col6, #T_4d490_row0_col7, #T_4d490_row0_col8, #T_4d490_row0_col9, #T_4d490_row1_col1, #T_4d490_row1_col2, #T_4d490_row1_col3, #T_4d490_row1_col4, #T_4d490_row1_col5, #T_4d490_row1_col6, #T_4d490_row1_col7, #T_4d490_row1_col8, #T_4d490_row1_col9, #T_4d490_row2_col2, #T_4d490_row2_col3, #T_4d490_row2_col4, #T_4d490_row2_col5, #T_4d490_row2_col6, #T_4d490_row2_col7, #T_4d490_row2_col8, #T_4d490_row2_col9, #T_4d490_row3_col3, #T_4d490_row3_col4, #T_4d490_row3_col5, #T_4d490_row3_col6, #T_4d490_row3_col7, #T_4d490_row3_col8, #T_4d490_row3_col9, #T_4d490_row4_col4, #T_4d490_row4_col5, #T_4d490_row4_col6, #T_4d490_row4_col7, #T_4d490_row4_col8, #T_4d490_row4_col9, #T_4d490_row5_col5, #T_4d490_row5_col6, #T_4d490_row5_col7, #T_4d490_row5_col8, #T_4d490_row5_col9, #T_4d490_row6_col6, #T_4d490_row6_col7, #T_4d490_row6_col8, #T_4d490_row6_col9, #T_4d490_row7_col7, #T_4d490_row7_col8, #T_4d490_row7_col9, #T_4d490_row8_col8, #T_4d490_row8_col9, #T_4d490_row9_col9 {
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: #f1f1f1;
# }
# #T_4d490_row1_col0 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_4d490_row2_col0, #T_4d490_row9_col1 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_4d490_row2_col1 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_4d490_row3_col0, #T_4d490_row9_col4, #T_4d490_row9_col8 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_4d490_row3_col1, #T_4d490_row4_col2, #T_4d490_row5_col0, #T_4d490_row7_col4 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_4d490_row3_col2, #T_4d490_row4_col3, #T_4d490_row7_col2, #T_4d490_row7_col5, #T_4d490_row7_col6 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_4d490_row4_col0 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_4d490_row4_col1 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_4d490_row5_col1, #T_4d490_row6_col5 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_4d490_row5_col2, #T_4d490_row8_col5, #T_4d490_row8_col6 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_4d490_row5_col3, #T_4d490_row6_col2, #T_4d490_row7_col0, #T_4d490_row8_col4, #T_4d490_row9_col7 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T